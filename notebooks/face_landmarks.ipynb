DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (317, 402): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (81, 82): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (91, 181): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (37, 0): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (84, 17): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (269, 270): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (321, 375): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (318, 324): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (312, 311): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (415, 308): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (17, 314): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (61, 146): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (78, 95): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (0, 267): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (82, 13): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (314, 405): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (178, 87): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (267, 269): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (61, 185): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (14, 317): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (88, 178): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (185, 40): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (405, 321): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (13, 312): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (324, 308): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (409, 291): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (146, 91): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (87, 14): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (78, 191): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (95, 88): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (311, 310): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (39, 37): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (40, 39): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (402, 318): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (191, 80): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (80, 81): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (310, 415): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (181, 84): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (375, 291): DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2), (374, 380): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (390, 373): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (249, 390): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (385, 384): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (373, 374): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (263, 466): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (387, 386): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (381, 382): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (384, 398): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (466, 388): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (386, 385): DrawingSpec(color=(48, 255, 48), thickness=2, circle_radius=2), (388, 387): DrawingSpec(color=(48, 25 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> app = FaceLandmarkerApp()
# ----> <a href='vscode-notebook-cell:/Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> app.run()
#
# File ~/daltunay/src/computer_vision/landmarks/base.py:54, in BaseLandmarkerApp.run(self)
#      51 landmarks_list_raw = getattr(detection_result, self.landmarks_type)
#      52 landmarks_list = landmarks_list_raw[0] if landmarks_list_raw else []
# ---> 54 self.plot_landmarks(
#      55     landmarks_list=landmarks_list,
#      56     connections_list=self.connections_list,
#      57     drawing_specs_list=self.drawing_specs_list,
#      58 )
#      60 t = time.time() - t0
#      61 self.landmarks_series.append(
#      62     {
#      63         "time": t,
#      64         "landmarks_list": landmarks_list,
#      65     },
#      66 )
#
# File ~/daltunay/src/computer_vision/landmarks/base.py:155, in BaseLandmarkerApp.plot_landmarks(cls, landmarks_list, connections_list, drawing_specs_list)
#     153 print(f"{connections=}", f"{type(connections)=}")
#     154 print(f"{drawing_specs=}", f"{type(drawing_specs)=}")
# --> 155 mp.solutions.drawing_utils.plot_landmarks(
#     156     landmarks_list=normalized_landmarks_list,
#     157     connections=connections,
#     158     elevation=10,
#     159     azimuth=10,
#     160     **drawing_specs,
#     161 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/daltunay-b5-VQK2U-py3.11/lib/python3.11/site-packages/mediapipe/python/solutions/drawing_utils.py:314, in plot_landmarks(landmarks_list, connections, landmark_drawing_spec, connection_drawing_spec, elevation, azimuth)
#     306     if start_idx in plotted_landmarks and end_idx in plotted_landmarks:
#     307       landmark_pair = [
#     308           plotted_landmarks[start_idx], plotted_landmarks[end_idx]
#     309       ]
#     310       ax.plot3D(
#     311           xs=[landmark_pair[0][0], landmark_pair[1][0]],
#     312           ys=[landmark_pair[0][1], landmark_pair[1][1]],
#     313           zs=[landmark_pair[0][2], landmark_pair[1][2]],
# --> 314           color=_normalize_color(connection_drawing_spec.color[::-1]),
#     315           linewidth=connection_drawing_spec.thickness)
#     316 plt.show()
#
# AttributeError: 'dict' object has no attribute 'color'

# %%
import mediapipe as mp
mp.solutions.drawing_styles.get_default_face_mesh_tesselation_style()
# Out:
# DrawingSpec(color=(128, 128, 128), thickness=1, circle_radius=2)

# %%
app = PoseLandmarkerApp()
app.run()
