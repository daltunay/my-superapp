# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /Users/DANIEL/daltunay

# %%
from utils.secrets import load_secrets

load_secrets()

# %%
from src.computer_vision.landmarks import FaceLandmarkerApp, PoseLandmarkerApp

# %%
app = FaceLandmarkerApp()
app.run()
# Out:
# I0000 00:00:1701181231.337145       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1 Pro
# W0000 00:00:1701181231.337508       1 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> app = FaceLandmarkerApp()
# ----> <a href='vscode-notebook-cell:/Users/DANIEL/daltunay/notebooks/face_landmarks.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> app.run()
#
# File ~/daltunay/src/computer_vision/landmarks/base.py:54, in BaseLandmarkerApp.run(self)
#      51 landmarks_list_raw = getattr(detection_result, self.landmarks_type)
#      52 landmarks_list = landmarks_list_raw[0] if landmarks_list_raw else []
# ---> 54 ax = self.plot_landmarks(
#      55     landmarks_list=landmarks_list,
#      56     connections_list=self.connections_list,
#      57     drawing_specs_list=self.drawing_specs_list,
#      58 )
#      60 t = time.time() - t0
#      61 self.history.append(
#      62     {
#      63         "time": t,
#    (...)
#      66     },
#      67 )
#
# File ~/daltunay/src/computer_vision/landmarks/base.py:169, in BaseLandmarkerApp.plot_landmarks(cls, landmarks_list, connections_list, drawing_specs_list, elevation, azimuth)
#     165 if (landmark.HasField("visibility") and landmark.visibility < 0.5) or (
#     166     landmark.HasField("presence") and landmark.presence < 0.5
#     167 ):
#     168     continue
# --> 169 for landmark_drawing_spec in {
#     170     drawing_specs["landmark_drawing_spec"]
#     171     for drawing_specs in drawing_specs_list
#     172 }:
#     173     ax.scatter3D(
#     174         xs=[-landmark.z],
#     175         ys=[landmark.x],
#    (...)
#     180         linewidth=landmark_drawing_spec.thickness,
#     181     )
#     182 plotted_landmarks[idx] = (-landmark.z, landmark.x, -landmark.y)
#
# File ~/daltunay/src/computer_vision/landmarks/base.py:169, in <setcomp>(.0)
#     165 if (landmark.HasField("visibility") and landmark.visibility < 0.5) or (
#     166     landmark.HasField("presence") and landmark.presence < 0.5
#     167 ):
#     168     continue
# --> 169 for landmark_drawing_spec in {
#     170     drawing_specs["landmark_drawing_spec"]
#     171     for drawing_specs in drawing_specs_list
#     172 }:
#     173     ax.scatter3D(
#     174         xs=[-landmark.z],
#     175         ys=[landmark.x],
#    (...)
#     180         linewidth=landmark_drawing_spec.thickness,
#     181     )
#     182 plotted_landmarks[idx] = (-landmark.z, landmark.x, -landmark.y)
#
# TypeError: unhashable type: 'DrawingSpec'

# %%
app = PoseLandmarkerApp()
app.run()

# %%
import mediapipe as mp

mp.solutions.drawing_utils.DrawingSpec()
# Out:
# mediapipe.python.solutions.drawing_utils.DrawingSpec
